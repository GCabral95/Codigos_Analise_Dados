# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('idadeserieneeracadez19.csv',sep=";")
df
# Out:
#         dre   codes       tipoesc                    nomesc    distrito  \
# 0        BT     191  EMEF          ALIPIO CORREA NETO, PROF  VILA SONIA
# 1        BT     191  EMEF          ALIPIO CORREA NETO, PROF  VILA SONIA
# 2        BT     191  EMEF          ALIPIO CORREA NETO, PROF  VILA SONIA
# 3        BT     191  EMEF          ALIPIO CORREA NETO, PROF  VILA SONIA
# 4        BT     191  EMEF          ALIPIO CORREA NETO, PROF  VILA SONIA
# 5        BT     191  EMEF          ALIPIO CORREA NETO, PROF  VILA SONIA
# 6        BT     191  EMEF          ALIPIO CORREA NETO, PROF  VILA SONIA
# 7        BT     191  EMEF          ALIPIO CORREA NETO, PROF  VILA SONIA
# 8        BT     191  EMEF          ALIPIO CORREA NETO, PROF  VILA SONIA
# 9        BT     191  EMEF          ALIPIO CORREA NETO, PROF  VILA SONIA
# 10       BT     191  EMEF          ALIPIO CORREA NETO, PROF  VILA SONIA
# 11       BT     191  EMEF          ALIPIO CORREA NETO, PROF  VILA SONIA
# ...
