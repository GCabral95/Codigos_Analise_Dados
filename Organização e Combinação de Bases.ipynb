# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Indexacao Hierarquica

# %%
txs2 = pd.Series(np.random.randn(10),
                index=[['a','a','a','b','b','b','c','c', 'd','d'],
                 [1,2,3,1,4,5,1,4,2,6]])

# %%
txs2 #Series com dois niveis de indice (letras e numeros)
# Out:
# a  1    0.314124
#    2    1.634230
#    3   -0.832233
# b  1    0.445342
#    4   -1.353751
#    5   -0.323032
# c  1    0.169558
#    4    0.036641
# d  2   -2.692111
#    6   -1.131276
# dtype: float64

# %%
txs2.loc[['a','c']] #selecionar os valores por uma lista de índices
# Out:
# a  1    0.314124
#    2    1.634230
#    3   -0.832233
# c  1    0.169558
#    4    0.036641
# dtype: float64

# %%
txs2.loc[:,3] #todos os niveis superiores de index e com o 3 como index inferior
# Out:
# a   -0.832233
# dtype: float64

# %%
txs2.unstack() #cria uma tabela cruzada a partir dos index
# Out:
#           1         2         3         4         5         6
# a  0.314124  1.634230 -0.832233       NaN       NaN       NaN
# b  0.445342       NaN       NaN -1.353751 -0.323032       NaN
# c  0.169558       NaN       NaN  0.036641       NaN       NaN
# d       NaN -2.692111       NaN       NaN       NaN -1.131276

# %% [markdown]
# # Joins

# %% [markdown]
# * Hipóteses de Join Many-To-One

# %%
df1 = pd.DataFrame({'x': ['br','br','arg','arg','def','def','br','arg'], 'y': range(8)})
df2 = pd.DataFrame({'x': ['def','br','arg','xas'], 'w': range(4)})

# %%
df1
# Out:
#      x  y
# 0   br  0
# 1   br  1
# 2  arg  2
# 3  arg  3
# 4  def  4
# 5  def  5
# 6   br  6
# 7  arg  7

# %%
df2
# Out:
#      x  w
# 0  def  0
# 1   br  1
# 2  arg  2
# 3  xas  3

# %%
pd.merge(df1,df2, on = 'x') #join many-to-one,df1 tem varios valores e df2 e df1 apenas um
#Observa-se que o valor 'xas' não consta no merge, pois o merge, por definicao, realiza um join no modelo inner
# Out:
#      x  y  w
# 0   br  0  1
# 1   br  1  1
# 2   br  6  1
# 3  arg  2  2
# 4  arg  3  2
# 5  arg  7  2
# 6  def  4  0
# 7  def  5  0

# %%
pd.merge(df1,df2, on = 'x', how = 'outer') # o how pode ser outer, left ou right
# Out:
#      x    y  w
# 0   br  0.0  1
# 1   br  1.0  1
# 2   br  6.0  1
# 3  arg  2.0  2
# 4  arg  3.0  2
# 5  arg  7.0  2
# 6  def  4.0  0
# 7  def  5.0  0
# 8  xas  NaN  3

# %% [markdown]
# * Hipóteses de Join Many-To-Many

# %%
df1 = pd.DataFrame({'x': ['br','br','arg','arg','def','def','br','arg'], 'y': range(8)})
df2 = pd.DataFrame({'x': ['def','br','arg','arg','br','def'], 'w': range(6)})

# %%
df1
# Out:
#      x  y
# 0   br  0
# 1   br  1
# 2  arg  2
# 3  arg  3
# 4  def  4
# 5  def  5
# 6   br  6
# 7  arg  7

# %%
df2
# Out:
#      x  w
# 0  def  0
# 1   br  1
# 2  arg  2
# 3  arg  3
# 4   br  4
# 5  def  5

# %%
pd.merge(df1,df2,on='x') #como são multiplos valores em cada tabela, cada combinação possível é inclusa
# Out:
#       x  y  w
# 0    br  0  1
# 1    br  0  4
# 2    br  1  1
# 3    br  1  4
# 4    br  6  1
# 5    br  6  4
# 6   arg  2  2
# 7   arg  2  3
# 8   arg  3  2
# 9   arg  3  3
# 10  arg  7  2
# 11  arg  7  3
# 12  def  4  0
# 13  def  4  5
# 14  def  5  0
# 15  def  5  5

# %% [markdown]
# * Multiplas chaves para merge

# %%
df1 = pd.DataFrame({'caract_1': ['azul','azul','vermelho'], 'caract_2': ['amarelo','verde','cinza'], 
                    'var': [5,6,9]})

# %%
df2 = pd.DataFrame({'caract_1': ['azul','vermelho','azul','vermelho'], 'caract_2': ['amarelo','verde','cinza','verde'], 
                    'var': [11,6,3,5]})

# %%
pd.merge(df1,df2, on=['caract_1','caract_2'], how='outer') #somente a combinacao de chaves azul/amarelo possui valores em
# ambas tabelas
# Out:
#    caract_1 caract_2  var_x  var_y
# 0      azul  amarelo    5.0   11.0
# 1      azul    verde    6.0    NaN
# 2  vermelho    cinza    9.0    NaN
# 3  vermelho    verde    NaN    6.0
# 4  vermelho    verde    NaN    5.0
# 5      azul    cinza    NaN    3.0

# %% [markdown]
# * Concatenação

# %%
df1 = pd.DataFrame({'x': ['br','br','arg','arg','def','def','br','arg'], 'y': range(8)})
df2 = pd.DataFrame({'x': ['def','br','arg','xas'], 'y': range(4)})

# %%
pd.concat([df1,df2]) #empilha as tabelas por linhas
# Out:
#      x  y
# 0   br  0
# 1   br  1
# 2  arg  2
# 3  arg  3
# 4  def  4
# 5  def  5
# 6   br  6
# 7  arg  7
# 0  def  0
# 1   br  1
# 2  arg  2
# 3  xas  3

# %%
pd.concat([df1,df2],axis=1) #com axis=1, empilha em forma de coluna
# Out:
#      x  y    x    y
# 0   br  0  def  0.0
# 1   br  1   br  1.0
# 2  arg  2  arg  2.0
# 3  arg  3  xas  3.0
# 4  def  4  NaN  NaN
# 5  def  5  NaN  NaN
# 6   br  6  NaN  NaN
# 7  arg  7  NaN  NaN

# %% [markdown]
# # Tabelas Pivotadas

# %%
df = pd.DataFrame({
    'X' : ['A','A','A','B','B','B'],
    'Y' : [4,7,12,56,26,78],
    'W' : [10,20,30,40,50,60],
    'Z' : ['C','C','D','D','E','E']
})

# %%
df.head(6)
# Out:
#    X   Y   W  Z
# 0  A   4  10  C
# 1  A   7  20  C
# 2  A  12  30  D
# 3  B  56  40  D
# 4  B  26  50  E
# 5  B  78  60  E

# %%
pd.pivot_table(df,index=["Z"]) #pivota pela coluna Z, calculando a média das variaveis quanti
# Out:
#     W     Y
# Z
# C  15   5.5
# D  35  34.0
# E  55  52.0

# %%
pd.pivot_table(df,index=["Z","X"]).reset_index() #idem ao acima, só que pivotando por duas colunas (Z e X)
# Out:
#    Z  X   W     Y
# 0  C  A  15   5.5
# 1  D  A  30  12.0
# 2  D  B  40  56.0
# 3  E  B  55  52.0

# %%
pd.pivot_table(df,index=["Z","X"], values=['Y']).reset_index() #escolhendo uma variavel quanti especifica
# Out:
#    Z  X     Y
# 0  C  A   5.5
# 1  D  A  12.0
# 2  D  B  56.0
# 3  E  B  52.0

# %%
pd.pivot_table(df,index=["Z","X"], values=['Y'], aggfunc = [np.sum,len]).reset_index()
#especificando funções para as variaveis quanti, neste caso, soma e contagem
# Out:
#    Z  X  sum len
#            Y   Y
# 0  C  A   11   2
# 1  D  A   12   1
# 2  D  B   56   1
# 3  E  B  104   2
