# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('pokemon.csv')

# %%
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost      ...       percentage_male  \
# 0             2.0            1.0      ...                  88.1
# ...

# %%
#Quantos missings há nas colunas
df.isna().sum()
# Out:
# abilities              0
# against_bug            0
# against_dark           0
# against_dragon         0
# against_electric       0
# against_fairy          0
# against_fight          0
# against_fire           0
# against_flying         0
# against_ghost          0
# against_grass          0
# against_ground         0
# against_ice            0
# against_normal         0
# against_poison         0
# against_psychic        0
# against_rock           0
# against_steel          0
# against_water          0
# attack                 0
# base_egg_steps         0
# base_happiness         0
# base_total             0
# capture_rate           0
# classfication          0
# defense                0
# experience_growth      0
# height_m              20
# hp                     0
# japanese_name          0
# name                   0
# percentage_male       98
# pokedex_number         0
# sp_attack              0
# sp_defense             0
# speed                  0
# type1                  0
# ...

# %%
#tipos das colunas
df.dtypes
# Out:
# abilities             object
# against_bug          float64
# against_dark         float64
# against_dragon       float64
# against_electric     float64
# against_fairy        float64
# against_fight        float64
# against_fire         float64
# against_flying       float64
# against_ghost        float64
# against_grass        float64
# against_ground       float64
# against_ice          float64
# against_normal       float64
# against_poison       float64
# against_psychic      float64
# against_rock         float64
# against_steel        float64
# against_water        float64
# attack                 int64
# base_egg_steps         int64
# base_happiness         int64
# base_total             int64
# capture_rate          object
# classfication         object
# defense                int64
# experience_growth      int64
# height_m             float64
# hp                     int64
# japanese_name         object
# name                  object
# percentage_male      float64
# ...

# %%
df.columns.tolist() #exportar nome das colunas para usar nos codigos
# Out:
# ['abilities',
#  'against_bug',
#  'against_dark',
#  'against_dragon',
#  'against_electric',
#  'against_fairy',
#  'against_fight',
#  'against_fire',
#  'against_flying',
#  'against_ghost',
#  'against_grass',
#  'against_ground',
#  'against_ice',
#  'against_normal',
#  'against_poison',
#  'against_psychic',
#  'against_rock',
#  'against_steel',
#  'against_water',
#  'attack',
#  'base_egg_steps',
#  'base_happiness',
#  'base_total',
#  'capture_rate',
#  'classfication',
#  'defense',
#  'experience_growth',
#  'height_m',
#  'hp',
#  'japanese_name',
#  'name',
#  'percentage_male',
#  'pokedex_number',
#  'sp_attack',
#  'sp_defense',
#  'speed',
#  'type1',
#  'type2',
#  'weight_kg',
#  'generation',
#  'is_legendary']

# %%
# Conta a quantidade de valores únicos
pd.value_counts(df['type1'])
# Out:
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# ground       32
# poison       32
# dark         29
# fighting     28
# ghost        27
# dragon       27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: type1, dtype: int64

# %%
# Consulta pokemon de tipo fogo com ataque especial maior que 140
df.loc[(df['type1']=='fire') & (df['sp_attack'] > 140)]
# Out:
#                                         abilities  against_bug  against_dark  \
# 5                        ['Blaze', 'Solar Power']         0.25           1.0
# 322  ['Magma Armor', 'Solid Rock', 'Anger Point']         0.50           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 5               1.0               2.0            0.5            0.5
# 322             1.0               0.0            0.5            1.0
#
#      against_fire  against_flying  against_ghost      ...       \
# 5             0.5             1.0            1.0      ...
# 322           0.5             1.0            1.0      ...
#
#      percentage_male  pokedex_number  sp_attack  sp_defense  speed  type1  \
# 5               88.1               6        159         115    100   fire
# 322             50.0             323        145         105     20   fire
#
#       type2  weight_kg  generation  is_legendary
# 5    flying       90.5           1             0
# ...

# %%
df.loc[0:4,'sp_attack':'speed'] #consultando da linha 0 até 4 e da coluna sp_attack ate speed
# Out:
#    sp_attack  sp_defense  speed
# 0         65          65     45
# 1         80          80     60
# 2        122         120     80
# 3         60          50     65
# 4         80          65     80

# %%
df.loc[[0, 3], ['sp_attack', 'speed']] #consultando por uma lista de linhas e colunas
# Out:
#    sp_attack  speed
# 0         65     45
# 3         60     65

# %%
#Consulta por critérios
criterio1 = df.sp_attack > 120
criterio2= df.type1 == 'water'
criterio3= df.generation == 3
df[criterio1 & criterio2 & criterio3]
# Out:
#        abilities  against_bug  against_dark  against_dragon  against_electric  \
# 381  ['Drizzle']          1.0           1.0             1.0               2.0
#
#      against_fairy  against_fight  against_fire  against_flying  \
# 381            1.0            1.0           0.5             1.0
#
#      against_ghost      ...       percentage_male  pokedex_number  sp_attack  \
# 381            1.0      ...                   NaN             382        180
#
#      sp_defense  speed  type1  type2  weight_kg  generation  is_legendary
# 381         160     90  water    NaN      352.0           3             1
#
# [1 rows x 41 columns]

# %%
#Obter os valores unicos de uma coluna
df['type1'].unique()
# Out:
# array(['grass', 'fire', 'water', 'bug', 'normal', 'poison', 'electric',
#        'ground', 'fairy', 'fighting', 'psychic', 'rock', 'ghost', 'ice',
#        'dragon', 'dark', 'steel', 'flying'], dtype=object)

# %%
#Filtrar valores por condicoes em uma lista
df[df.type1.isin(['poison','steel'])]
# Out:
#                                              abilities  against_bug  \
# 22              ['Intimidate', 'Shed Skin', 'Unnerve']         0.50
# 23              ['Intimidate', 'Shed Skin', 'Unnerve']         0.50
# 28               ['Poison Point', 'Rivalry', 'Hustle']         0.50
# 29               ['Poison Point', 'Rivalry', 'Hustle']         0.50
# 30          ['Poison Point', 'Rivalry', 'Sheer Force']         0.50
# 31               ['Poison Point', 'Rivalry', 'Hustle']         0.50
# 32               ['Poison Point', 'Rivalry', 'Hustle']         0.50
# 33          ['Poison Point', 'Rivalry', 'Sheer Force']         0.50
# 40                      ['Inner Focus', 'Infiltrator']         0.25
# 41                      ['Inner Focus', 'Infiltrator']         0.25
# 87   ['Stench', 'Sticky Hold', 'Poison Touch', 'Poi...         0.50
# 88   ['Stench', 'Sticky Hold', 'Poison Touch', 'Poi...         0.50
# 108                                       ['Levitate']         0.50
# ...

# %%
#Filtrar termos/palavras dentro de uma variavel
df[df['type1'].str.contains('fly')]
# Out:
#                                    abilities  against_bug  against_dark  \
# 640  ['Prankster', 'Defiant', 'Regenerator']          0.5           1.0
# 713    ['Frisk', 'Infiltrator', 'Telepathy']          0.5           1.0
# 714    ['Frisk', 'Infiltrator', 'Telepathy']          0.5           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 640             1.0               2.0            1.0            0.5
# 713             2.0               1.0            2.0            0.5
# 714             2.0               1.0            2.0            0.5
#
#      against_fire  against_flying  against_ghost      ...       \
# 640           1.0             1.0            1.0      ...
# 713           0.5             1.0            1.0      ...
# 714           0.5             1.0            1.0      ...
#
#      percentage_male  pokedex_number  sp_attack  sp_defense  speed   type1  \
# 640            100.0             641        110          90    121  flying
# ...

# %%
#Numero de linhas por condicao
(df.type1 == "water").sum()
# Out:
# 114

# %%
#Porcentagem de linhas naquela condicao
(df.sp_attack > 130).mean()
# Out:
# 0.05118601747815231

# %%
#Agregar dados por varias funcoes
df.groupby('type1').sp_attack.agg(['mean','max']) #maior e media de especial ataque por tipo
# Out:
#                mean  max
# type1
# bug       56.652778  145
# dark      74.517241  140
# dragon    89.592593  180
# electric  87.538462  173
# fairy     81.500000  131
# fighting  50.107143  140
# fire      87.730769  159
# flying    84.000000  110
# ghost     82.444444  170
# grass     74.320513  145
# ground    51.937500  150
# ice       77.434783  130
# normal    56.980952  135
# poison    61.562500  111
# psychic   92.603774  194
# rock      63.200000  160
# steel     72.708333  150
# water     74.061404  180

# %%
#Agregar dados por varias colunas e funcoes com uma variavel numerica
df.groupby(['type1','type2']).sp_attack.agg(['mean','max']) #maior e media de especial ataque por tipo
# Out:
#                          mean  max
# type1    type2
# bug      electric   88.500000  145
#          fairy      75.000000   95
#          fighting   76.666667  137
#          fire       92.500000  135
#          flying     75.000000  116
#          ghost      30.000000   30
#          grass      55.666667   70
#          ground     30.000000   30
#          poison     42.272727   90
#          rock       36.666667   65
#          steel      70.600000  120
#          water      43.333333   60
# dark     dragon     83.000000  125
#          fighting   40.000000   45
#          fire      110.000000  140
#          flying     84.200000  131
#          ghost      85.000000   85
#          ice        40.000000   45
#          psychic    52.500000   68
#          steel      50.000000   60
# dragon   electric  120.000000  120
#          fighting   82.500000  100
#          fire      150.000000  150
#          flying    127.500000  180
#          ground     75.250000  120
# ...

# %%
#Agregar os dados por multiplas colunas numericas
df.groupby('type1').agg({'speed':['mean','max'], #média e maximo velocidade
                         'sp_defense': ['mean','min']}) #media e minimo defesa especial
# Out:
#               speed      sp_defense
#                mean  max       mean min
# type1
# bug       63.569444  160  62.513889  20
# dark      75.310345  125  69.068966  30
# dragon    76.111111  120  84.555556  30
# electric  85.410256  150  70.051282  32
# fairy     53.666667  100  87.777778  40
# fighting  64.285714  118  63.428571  30
# fire      73.346154  126  71.538462  40
# flying    99.666667  123  70.000000  40
# ghost     58.333333  130  78.296296  33
# grass     59.025641  145  69.230769  30
# ground    59.968750  110  62.281250  30
# ice       62.739130  110  76.130435  30
# normal    69.533333  135  63.200000  20
# poison    64.187500  130  65.531250  40
# psychic   75.150943  180  85.735849  31
# rock      57.422222  150  73.377778  25
# steel     56.583333  110  82.208333  37
# water     63.921053  132  71.798246  20

# %%
#Agrupando a partir de associaçao de colunas
habilidades_tot = {'sp_attack': 'ataque', 'attack': 'ataque', 'sp_defense': 'defesa', 'defense': 'defesa'}

# %%
df2 = df[['name','sp_attack','attack','sp_defense','defense']]
df2.set_index('name', inplace=True)

# %%
df2.head()
# Out:
#             sp_attack  attack  sp_defense  defense
# name
# Bulbasaur          65      49          65       49
# Ivysaur            80      62          80       63
# Venusaur          122     100         120      123
# Charmander         60      52          50       43
# Charmeleon         80      64          65       58

# %%
(df2.groupby(habilidades_tot, axis=1).sum()).head()
# Out:
#             ataque  defesa
# name
# Bulbasaur      114     114
# Ivysaur        142     143
# Venusaur       222     243
# Charmander     112      93
# Charmeleon     144     123

# %%
#Agrupando por uma função criada
def dif_quantil(x):
    return (x.quantile(0.9) - x.quantile(0.1))

# %%
df.groupby('type1')[['attack','defense']].agg(dif_quantil)
# Out:
#           attack  defense
# type1
# bug         94.5     74.7
# dark        70.0     66.6
# dragon      80.6     70.6
# electric    67.0     50.6
# fairy       57.9     46.2
# fighting    63.6     50.1
# fire        64.8     64.5
# flying      56.0     36.0
# ghost       76.0     84.8
# grass       70.8     68.0
# ground      73.9     75.0
# ice         69.4     60.0
# normal      76.0     64.6
# poison      52.2     54.1
# psychic     86.0     68.2
# rock        88.0     98.0
# steel       76.0     68.2
# water       65.0     66.9

# %%
#Agrupando por frações da base
faixas_peso = [0,250,500,750,1000]
grupos = pd.cut(df['weight_kg'],faixas_peso)

# %%
df.groupby(grupos)[['attack','sp_attack']].mean()
# Out:
#                  attack   sp_attack
# weight_kg
# (0, 250]      75.713137   70.703753
# (250, 500]   121.500000   90.115385
# (500, 750]   125.500000  104.750000
# (750, 1000]  107.200000   87.600000

# %%
#Agrupando por quantil
grupos = pd.qcut(df['weight_kg'],[0, 0.2,0.5,0.8,1])

# %%
df.groupby(grupos)[['attack','sp_attack']].mean()
# Out:
#                    attack  sp_attack
# weight_kg
# (0.099, 7.0]    57.188679  58.710692
# (7.0, 27.3]     66.663793  63.228448
# (27.3, 81.9]    85.059829  79.294872
# (81.9, 999.9]  103.948718  85.807692
